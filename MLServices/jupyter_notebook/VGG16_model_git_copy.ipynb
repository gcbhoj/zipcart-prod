# %%
from keras.applications import vgg16

img_rows = 100
img_cols = 100 

model =   vgg16.VGG16(weights = 'imagenet', 
                     include_top = False, 
                     input_shape = (img_rows, img_cols, 3))
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1788991750.569795    3230 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1788991750.576797    3230 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1788991751.594387    3230 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1788991759.032504    3230 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1788991759.036377    3230 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# E0000 00:00:1788991764.006290    3230 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
for layer in model.layers:
    layer.trainable = False
 
for (i,layer) in enumerate(model.layers):
    print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 Conv2D False
# 3 MaxPooling2D False
# 4 Conv2D False
# 5 Conv2D False
# 6 MaxPooling2D False
# 7 Conv2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 MaxPooling2D False
# 11 Conv2D False
# 12 Conv2D False
# 13 Conv2D False
# 14 MaxPooling2D False
# 15 Conv2D False
# 16 Conv2D False
# 17 Conv2D False
# 18 MaxPooling2D False

# %%
def addTopModel(bottom_model, num_classes, D=256):
    """creates the top or head of the model that will be 
    placed ontop of the bottom layers"""
    top_model = bottom_model.output
    top_model = Flatten(name = "flatten")(top_model)
    # top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(D, activation = "relu")(top_model)
    top_model = Dropout(0.3)(top_model)
    top_model = Dense(num_classes, activation = "softmax")(top_model)
    return top_model

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
#from keras.layers.normalization import BatchNormalization
from keras.models import Model

num_classes = 436

FC_Head = addTopModel(model, num_classes)

modelnew = Model(inputs=model.input, outputs=FC_Head)

print(modelnew.summary())
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 100, 100, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 100, 100, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 100, 100, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 50, 50, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 50, 50, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 50, 50, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 25, 25, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 25, 25, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 25, 25, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 25, 25, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 12, 12, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 12, 12, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 12, 12, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 6, 6, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 436)            │       112,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,006,644 (61.06 MB)
#  Trainable params: 1,291,956 (4.93 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# None

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator




train_data_dir = "../data/fruits_veg_data/Training"
validation_data_dir = "../data/fruits_veg_data/Validation"
print("Training:", len(train_data_dir))
print("Validation:", len(validation_data_dir))

# class_names = sorted(
#     set(train_data_dir["label"])
# )

# print(class_names)
# print(len(class_names))

# # Create class -> integer mapping
# class_to_index = {
#     class_name: index
#     for index, class_name in enumerate(class_names)
# }

train_datagen = ImageDataGenerator(
      rescale=1./255,
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest')
 
validation_datagen = ImageDataGenerator(rescale=1./255)
 
train_batchsize = 64
val_batchsize = 64
 
train_batchsize = 64
val_batchsize = 64

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_rows, img_cols),
    batch_size=train_batchsize,
    class_mode="categorical",
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_rows, img_cols),
    batch_size=val_batchsize,
    class_mode="categorical",
    shuffle=False
)

num_classes = len(train_generator.class_indices)

class_to_index = train_generator.class_indices

class_names = list(class_to_index.keys())



print()
print("========================================")
print("Dataset Information")
print("========================================")
print("Training images:", train_generator.samples)
print("Validation images:", validation_generator.samples)
print("Number of classes:", num_classes)

print()
print("Class mapping:")
print(class_to_index)
import json

CLASS_NAMES_PATH = "../ML_models/class_names.json"

with open(CLASS_NAMES_PATH, "w") as file:
    json.dump(class_names, file, indent=4)

print(f"Class names saved to: {CLASS_NAMES_PATH}")
# Out:
# Training: 32
# Validation: 34
# Found 212076 images belonging to 436 classes.
# Found 186411 images belonging to 436 classes.
#
# ========================================
# Dataset Information
# ========================================
# Training images: 212076
# Validation images: 186411
# Number of classes: 436
#
# Class mapping:
# {'Almonds 1': 0, 'Apple 10': 1, 'Apple 11': 2, 'Apple 12': 3, 'Apple 13': 4, 'Apple 14': 5, 'Apple 17': 6, 'Apple 18': 7, 'Apple 19': 8, 'Apple 20': 9, 'Apple 21': 10, 'Apple 22': 11, 'Apple 23': 12, 'Apple 5': 13, 'Apple 6': 14, 'Apple 7': 15, 'Apple 8': 16, 'Apple 9': 17, 'Apple Braeburn 1': 18, 'Apple Red Yellow 2': 19, 'Avocado Black 1': 20, 'Avocado Black 2': 21, 'Avocado Green 1': 22, 'Banana 3': 23, 'Banana 4': 24, 'Bean pod 1': 25, 'Blackberry 1': 26, 'Blackberry 2': 27, 'Blackberry 3': 28, 'Blackberry 4': 29, 'Blackberry 5': 30, 'Cabbage red 1': 31, 'Cactus fruit green 1': 32, 'Cactus fruit red 1': 33, 'Caju seed 1': 34, 'Cantaloupe 3': 35, 'Carambola 2': 36, 'Carambola 3': 37, 'Carrot 1': 38, 'Celery 1': 39, 'Cherimoya 1': 40, 'Cherry 3': 41, 'Cherry 4': 42, 'Cherry 5': 43, 'Cherry Rainier 2': 44, 'Cherry Rainier 3': 45, 'Cherry Sour 1': 46, 'Cherry Wax 1': 47, 'Cherry Wax 2': 48, 'Cherry Wax Red 2': 49, 'Cherry Wax Red 3': 50, 'Chinese_artichoke': 51, 'Chinese_cabbage': 52, 'Chinese_chestnut': 53, 'Chinese_kale': 54, 'Chinese_mallow': 55, 'Chinese_pumpkin': 56, 'Chinese_yam': 57, 'Cucumber 1': 58, 'Cucumber 10': 59, 'Cucumber 11': 60, 'Cucumber 3': 61, 'Cucumber 4': 62, 'Cucumber 5': 63, 'Cucumber 6': 64, 'Cucumber 7': 65, 'Cucumber 8': 66, 'Cucumber 9': 67, 'Dangshan_Pear': 68, 'Dates 2': 69, 'Ginger 2': 70, 'Gooseberry 1': 71, 'Grape 1': 72, 'Grape pink 2': 73, 'Hami_melon': 74, 'Herb_of_Ghostplant_Wormwood': 75, "Jew's-ear": 76, 'Lily': 77, 'Nectarine Flat 2': 78, 'New_Zealand_spinach': 79, 'Nut 1': 80, 'Nut 2': 81, 'Nut 3': 82, 'Nut 4': 83, 'Nut 5': 84, 'Onion 2': 85, 'Onion Red 2': 86, 'Onion White 2': 87, 'Orange 2': 88, 'Orange 3': 89, 'Orange 4': 90, 'Orange peeled 1': 91, 'Papaya 2': 92, 'Peach 3': 93, 'Peach 4': 94, 'Peach 5': 95, 'Peach 6': 96, 'Peanut shell 1x 1': 97, 'Pear 1': 98, 'Pear 10': 99, 'Pear 11': 100, 'Pear 12': 101, 'Pear 13': 102, 'Pear 3': 103, 'Pear 5': 104, 'Pear 6': 105, 'Pear 7': 106, 'Pear 8': 107, 'Pear 9': 108, 'Pear common 1': 109, 'Pepper 1': 110, 'Pepper 2': 111, 'Pepper Orange 2': 112, 'Pepper Red 2': 113, 'Pepper Red 3': 114, 'Pepper Red 4': 115, 'Pepper Red 5': 116, 'Pistachio 1': 117, 'Plum 4': 118, 'Plum 5': 119, 'Quince 2': 120, 'Quince 3': 121, 'Quince 4': 122, 'Raspberry 2': 123, 'Raspberry 3': 124, 'Raspberry 4': 125, 'Raspberry 5': 126, 'Raspberry 6': 127, 'Strawberry 2': 128, 'Strawberry 3': 129, 'Tomato 1': 130, 'Tomato 10': 131, 'Tomato 5': 132, 'Tomato 7': 133, 'Tomato 8': 134, 'Tomato 9': 135, 'Tomato Cherry Maroon 1': 136, 'Tomato Cherry Orange 1': 137, 'Tomato Cherry Red 2': 138, 'Tomato Cherry Yellow 1': 139, 'Tomato Maroon 2': 140, 'Wuta-tsai': 141, 'Zucchini Green 1': 142, 'Zucchini dark 1': 143, 'achyranthes': 144, 'adenophora': 145, 'agaricus_bisporus': 146, 'agaricus_blazei_murill': 147, 'agrimony': 148, 'agrocybe_aegerita': 149, 'allium': 150, 'almond': 151, 'annona_muricata': 152, 'apple': 153, 'apple_crimson_snow_1': 154, 'apple_golden_1': 155, 'apple_golden_2': 156, 'apple_golden_3': 157, 'apple_granny_smith_1': 158, 'apple_pink_lady_1': 159, 'apple_red_1': 160, 'apple_red_2': 161, 'apple_red_3': 162, 'apple_red_delicios_1': 163, 'apple_red_yellow_1': 164, 'apricot': 165, 'arrowhead': 166, 'artemisia_selengensis': 167, 'artocarpus_heterophyllus': 168, 'asparagus': 169, 'asparagus_fern': 170, 'asparagus_lettuce': 171, 'asparagus_pea': 172, 'avocado': 173, 'azuki_beans': 174, 'balsam_pear': 175, 'bamboo_shoot': 176, 'banana': 177, 'basella_rubra': 178, 'basil': 179, 'bassia_scoparia': 180, 'bayberry': 181, 'beefsteak_plant': 182, 'beetroot': 183, 'bergamot_pear': 184, 'bird_pepper': 185, 'black_bean_sprouts': 186, 'black_currant': 187, 'black_grape': 188, 'black_salsify': 189, 'black_soya_bean': 190, 'blood_orange': 191, 'blueberry': 192, 'bolete': 193, 'bottle_gourd': 194, 'breadfruit': 195, 'broad_bean': 196, 'broccoli': 197, 'brussels_sprouts': 198, 'bunching_onion': 199, 'burclover': 200, 'burdock_root': 201, 'cabbage_white_1': 202, 'candied_date': 203 ...
# Class names saved to: ../ML_models/class_names.json

# %%
modelnew.compile(loss = 'categorical_crossentropy',
              optimizer =  "adam"  ,
              metrics = ['accuracy'])

nb_train_samples = len(train_data_dir)
nb_validation_samples = len(validation_data_dir)
epochs = 20
batch_size = 64

history = modelnew.fit(
    train_generator,
    # steps_per_epoch = nb_train_samples // batch_size,
    epochs = epochs,
    # callbacks = callbacks,
    validation_data = validation_generator,
    # validation_steps = nb_validation_samples // batch_size)
)

modelnew.save("../ML_models/fruits_veg_identify.keras")
# Out:
# Epoch 1/20
# I0000 00:00:1788991801.854591    3230 generator_dataset_op.cc:213] Memory patch applied: M_TRIM_THRESHOLD=128 kb was set.
#  770/3314 ━━━━━━━━━━━━━━━━━━━━ 1:04:40 2s/step - accuracy: 0.0597 - loss: 4.8756
# /usr/local/lib/python3.11/site-packages/PIL/Image.py:1136: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 1840/3314 ━━━━━━━━━━━━━━━━━━━━ 37:39 2s/step - accuracy: 0.1185 - loss: 4.3026
# /usr/local/lib/python3.11/site-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 8879s 3s/step - accuracy: 0.1609 - loss: 3.9608 - val_accuracy: 0.2014 - val_loss: 4.4229
# Epoch 2/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 7051s 2s/step - accuracy: 0.2516 - loss: 3.3082 - val_accuracy: 0.2217 - val_loss: 4.5274
# Epoch 3/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 7129s 2s/step - accuracy: 0.2721 - loss: 3.1975 - val_accuracy: 0.2354 - val_loss: 4.7496
# Epoch 4/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 6784s 2s/step - accuracy: 0.2844 - loss: 3.1323 - val_accuracy: 0.2428 - val_loss: 4.8775
# Epoch 5/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 6786s 2s/step - accuracy: 0.2917 - loss: 3.0972 - val_accuracy: 0.2448 - val_loss: 4.9762
# Epoch 6/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 6769s 2s/step - accuracy: 0.2956 - loss: 3.0793 - val_accuracy: 0.2541 - val_loss: 5.0833
# Epoch 7/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 6849s 2s/step - accuracy: 0.2993 - loss: 3.0584 - val_accuracy: 0.2500 - val_loss: 5.1005
# Epoch 8/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 7137s 2s/step - accuracy: 0.3033 - loss: 3.0421 - val_accuracy: 0.2591 - val_loss: 5.2575
# Epoch 9/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 7259s 2s/step - accuracy: 0.3054 - loss: 3.0330 - val_accuracy: 0.2566 - val_loss: 5.4781
# Epoch 10/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 6894s 2s/step - accuracy: 0.3075 - loss: 3.0188 - val_accuracy: 0.2566 - val_loss: 5.4892
# Epoch 11/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 6942s 2s/step - accuracy: 0.3088 - loss: 3.0186 - val_accuracy: 0.2514 - val_loss: 5.4425
# Epoch 12/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 7071s 2s/step - accuracy: 0.3106 - loss: 3.0128 - val_accuracy: 0.2606 - val_loss: 5.5412
# Epoch 13/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 6968s 2s/step - accuracy: 0.3109 - loss: 3.0052 - val_accuracy: 0.2612 - val_loss: 5.7417
# Epoch 14/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 7010s 2s/step - accuracy: 0.3121 - loss: 3.0023 - val_accuracy: 0.2608 - val_loss: 5.5781
# Epoch 15/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 6972s 2s/step - accuracy: 0.3134 - loss: 2.9969 - val_accuracy: 0.2594 - val_loss: 5.8584
# Epoch 16/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 6996s 2s/step - accuracy: 0.3143 - loss: 2.9963 - val_accuracy: 0.2580 - val_loss: 5.7589
# Epoch 17/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 7013s 2s/step - accuracy: 0.3153 - loss: 2.9918 - val_accuracy: 0.2639 - val_loss: 5.9138
# Epoch 18/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 7022s 2s/step - accuracy: 0.3160 - loss: 2.9901 - val_accuracy: 0.2634 - val_loss: 5.8796
# Epoch 19/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 7038s 2s/step - accuracy: 0.3165 - loss: 2.9887 - val_accuracy: 0.2647 - val_loss: 6.0827
# Epoch 20/20
# 3314/3314 ━━━━━━━━━━━━━━━━━━━━ 7129s 2s/step - accuracy: 0.3144 - loss: 2.9894 - val_accuracy: 0.2580 - val_loss: 6.0464
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image


def predict_single_image(img_path: str):
    """Load, display, and predict a single image."""

    print(f"\n--- Evaluation Request for: {img_path} ---")

    # Check if file exists
    if not os.path.exists(img_path):
        print(f"Error: Target path '{img_path}' does not exist.")
        return
    IMG_SIZE =(img_rows,img_cols)
    # Load image
    img = image.load_img(
        img_path,
        target_size=IMG_SIZE
    )

    # Display image
    plt.figure(figsize=(5, 5))
    plt.imshow(img)
    plt.axis("off")
    plt.show()

    # Convert image to NumPy array
    img_array = image.img_to_array(img)

    # Rescale exactly like the training generator
    img_array = img_array / 255.0

    # Add batch dimension: (224, 224, 3) -> (1, 224, 224, 3)
    img_batch = np.expand_dims(img_array, axis=0)

    # Make prediction
    predictions = modelnew.predict(img_batch, verbose=0)[0]

    # Get best prediction
    best_match_idx = np.argmax(predictions)
    confidence_score = predictions[best_match_idx]

    # Get class name
    predicted_class = class_names[best_match_idx]

    print()
    print("========================================")
    print("Prediction Result")
    print("========================================")
    print(
        f"Identified as: '{predicted_class}'"
    )
    print(
        f"Confidence: {confidence_score * 100:.2f}%"
    )

    # Display top 10 predictions
    top_n = 10

    top_indices = np.argsort(predictions)[-top_n:][::-1]

    print()
    print("Top Predictions")
    print("----------------------------------------")

    for rank, idx in enumerate(top_indices, start=1):
        print(
            f"{rank}. {class_names[idx]}: "
            f"{predictions[idx] * 100:.2f}%"
        )


# Test prediction
sample_test_path = "./banana1.jpg"

predict_single_image(sample_test_path)
# Out:
# --- Evaluation Request for: ./banana1.jpg ---
# ========================================
# Prediction Result
# ========================================
# Identified as: 'banana'
# Confidence: 51.21%
#
# Top Predictions
# ----------------------------------------
# 1. banana: 51.21%
# 2. pecans: 14.38%
# 3. pistachio: 5.47%
# 4. pumpkin: 3.37%
# 5. chicory: 3.00%
# 6. pineapple: 2.59%
# 7. green_eggplant: 1.05%
# 8. broad_bean: 1.05%
# 9. walnuts: 1.02%
# 10. eggplant: 0.82%
